# %%
import pandas as pd
import numpy as np

# %%
trip_Jun = pd.read_csv("trip_duration_data/201706-citibike-tripdata.csv")

# %%
trip_Jun.head()
# Out:
#    start station id  tripduration
# 0               515          1397
# 1               488          1103
# 2               461          1810
# 3              2009          1760
# 4               360          2165

# %%
ranked_data = pd.read_csv("rank_by_cum_time.csv")

# %%
unique_stations = ranked_data['station']

# %%
unique_stations = np.array(unique_stations)

# %%
unique_stations
# Out:
# array([  72,   79,   82,   83,  116,  119,  120,  127,  128,  143,  144,
#         146,  150,  151,  152,  153,  157,  161,  164,  167,  168,  173,
#         174,  195,  212,  216,  217,  223,  224,  228,  229,  232,  236,
#         237,  238,  239,  241,  242,  243,  244,  245,  247,  248,  249,
#         251,  252,  253,  254,  257,  258,  259,  260,  261,  262,  264,
#         265,  266,  267,  268,  270,  274,  275,  276,  278,  279,  280,
#         281,  282,  284,  285,  289,  291,  293,  295,  296,  297,  301,
#         302,  303,  304,  305,  306,  307,  308,  309,  310,  311,  312,
#         313,  314,  315,  316,  317,  319,  320,  321,  322,  323,  324,
#         325,  326,  327,  328,  330,  331,  332,  334,  335,  336,  337,
#         339,  340,  341,  342,  343,  344,  345,  346,  347,  348,  349,
#         350,  351,  353,  354,  355,  356,  357,  358,  359,  360,  361,
#         362,  363,  364,  365,  366,  368,  369,  372,  373,  376,  377,
# ...

# %%
station_duration = {}
for st in unique_stations:
    station_duration[st] = 0
    df = trip_Jun.loc[trip_Jun['start station id'] == st]
    station_duration[st] = sum(df['tripduration'])

# %%
station_duration
# Out:
# {72: 12312034,
#  79: 6959094,
#  82: 5558664,
#  83: 15466649,
#  116: 9250746,
#  119: 2208841,
#  120: 2339932,
#  127: 14830988,
#  128: 15997649,
#  143: 4863778,
#  144: 4950740,
#  146: 5954167,
#  150: 6043894,
#  151: 23547280,
#  152: 6712421,
#  153: 10683139,
#  157: 4495078,
#  161: 12591344,
#  164: 7163696,
#  167: 10416913,
#  168: 15037396,
#  173: 13495287,
#  174: 6688298,
#  195: 13753571,
#  212: 12795985,
#  216: 4035644,
#  217: 23036417,
#  223: 6788805,
#  224: 1739777,
#  228: 6455134,
#  229: 14396277,
#  232: 6046317,
#  236: 12862479,
#  237: 11787628,
#  238: 9260633,
#  239: 5088397,
#  241: 4203020,
#  242: 3471284,
#  243: 2747492,
#  244: 3533778,
#  245: 9463075,
#  247: 7023001,
#  248: 2700335,
#  249: 5141359,
#  251: 13587604,
#  252: 7921546,
#  253: 7204585,
#  254: 5775597,
#  257: 9738365,
#  258: 3779327,
#  259: 14253680,
#  260: 5075113,
#  261: 4810564,
#  262: 2344820,
#  264: 7082456,
#  265: 12926997,
#  266: 6953061,
# ...

# %%
len(station_duration)
# Out:
# 751

# %%
July_data = pd.read_csv("trip_duration_data/201707-citibike-tripdata.csv")

# %%
for st in unique_stations:
    df = July_data.loc[July_data['start station id'] == st]
    station_duration[st] += sum(df['tripduration'])

# %%
Aug_data = pd.read_csv("trip_duration_data/201708-citibike-tripdata.csv")

# %%
for st in unique_stations:
    df = Aug_data.loc[Aug_data['start station id'] == st]
    station_duration[st] += sum(df['tripduration'])

# %%
Sept_data = pd.read_csv("trip_duration_data/201709-citibike-tripdata.csv")

# %%
for st in unique_stations:
    df = Sept_data.loc[Sept_data['start station id'] == st]
    station_duration[st] += sum(df['tripduration'])

# %%
station_duration
# Out:
# {72: 17058703,
#  79: 8721961,
#  82: 6808909,
#  83: 17348578,
#  116: 12726742,
#  119: 2599092,
#  120: 3314874,
#  127: 20667388,
#  128: 22034047,
#  143: 6971147,
#  144: 6412858,
#  146: 8685357,
#  150: 8265835,
#  151: 31177967,
#  152: 9454856,
#  153: 10683139,
#  157: 6213872,
#  161: 18650244,
#  164: 10251921,
#  167: 14440924,
#  168: 22337537,
#  173: 18780704,
#  174: 10014194,
#  195: 18026565,
#  212: 16975853,
#  216: 5204171,
#  217: 29642255,
#  223: 10020442,
#  224: 1739777,
#  228: 8969412,
#  229: 20421675,
#  232: 8057625,
#  236: 17251171,
#  237: 16498530,
#  238: 12588110,
#  239: 6651499,
#  241: 5753062,
#  242: 4778666,
#  243: 3869972,
#  244: 4895110,
#  245: 10099345,
#  247: 9665797,
#  248: 3764688,
#  249: 7532752,
#  251: 18577927,
#  252: 11261430,
#  253: 11191164,
#  254: 7455472,
#  257: 13229579,
#  258: 5295250,
#  259: 19758400,
#  260: 6988486,
#  261: 6514804,
#  262: 3343890,
#  264: 9716116,
#  265: 17996150,
#  266: 8519820,
# ...

# %%
sorted_list = sorted(station_duration.items(),key=lambda kv: kv[1],reverse=True)

# %%
subset_selected = []
for i in range(round(len(sorted_list)*0.3)):
    subset_selected.append(sorted_list[i][0])

# %%
len(subset_selected)
# Out:
# 225

# %%
225/0.3
# Out:
# 750.0

# %%
s = [3254, 3267, 3199, 3202, 3276, 3192, 3186, 3183, 3213, 3072, 3178, 3290, 491, 3285, 3314, 411, 3165, 383, 527, 3357, 347, 474, 484, 504, 3244, 2021, 3282, 528, 529, 2008, 531, 518, 3383, 3427, 3443, 3137, 3139, 3156, 426, 3436, 3372, 3376, 3184, 363, 3134, 3163, 3283, 3286, 444, 472, 3293, 3295, 281, 514, 402, 3132, 285, 3164, 435, 423, 486, 3173, 3224, 537, 3056, 365, 252, 3146, 359, 387, 388, 405, 410, 3203, 3211, 152, 284, 434, 3129, 3151, 3323, 328, 490, 280, 540, 146, 3341, 3349, 3366, 3367, 3162, 3336, 3167, 503, 507, 315, 3150, 319, 229, 238, 442, 3226, 327, 446, 479, 499, 508, 513, 316, 335, 3145, 173, 3258, 127, 305, 309, 223, 356, 3320, 128, 296, 433, 3306, 3307, 3308, 3310, 2000, 3312, 3315, 2002, 3318, 2003, 3321, 3325, 3328, 3329, 3331, 2006, 432, 3297, 3298, 3346, 3303, 3351, 3356, 3304, 3358, 3360, 3361, 3362, 3370, 3311, 340, 422, 427, 430, 336, 539, 545, 3319, 546, 428, 523, 251, 397, 3148, 3288, 3158, 419, 3294, 332, 249, 396, 3141, 3142, 3292, 3263, 536, 248, 3289, 3259, 3260, 395, 3428, 3136, 3429, 3434, 3435, 3373, 3438, 3378, 3440, 3423, 3447, 3449, 3453, 3382, 3454, 3457, 3459, 3461, 3462, 3463, 3464, 3466, 519, 459, 497, 3002, 368, 358, 3256, 151, 293, 382, 168, 505, 462, 477, 3255, 379, 509, 457, 465, 3374]
len(s)
# Out:
# 225

# %%
sorted_list
# Out:
# [(281, 68672558),
#  (426, 58033347),
#  (514, 57155598),
#  (3068, 55345512),
#  (3042, 54720387),
#  (2006, 51657079),
#  (519, 50203347),
#  (387, 44615997),
#  (497, 39051063),
#  (3002, 38889871),
#  (3374, 38433035),
#  (459, 36605869),
#  (3255, 32458864),
#  (2008, 32139819),
#  (3256, 31889271),
#  (499, 31618625),
#  (151, 31177967),
#  (402, 31080984),
#  (3282, 30896294),
#  (490, 30401308),
#  (327, 30280758),
#  (217, 29642255),
#  (435, 29590346),
#  (523, 29094736),
#  (3137, 28923014),
#  (3165, 28734934),
#  (477, 28727624),
#  (3052, 28179262),
#  (3058, 28142718),
#  (359, 27991519),
#  (405, 27496615),
#  (457, 27370636),
#  (368, 27269227),
#  (358, 27035164),
#  (444, 26995174),
#  (3067, 26929576),
#  (3041, 26788881),
#  (304, 25727228),
#  (293, 25330064),
#  (285, 25286702),
#  (450, 24884746),
#  (3163, 24691436),
#  (3047, 24546335),
#  (279, 24358845),
#  (3435, 23999597),
#  (532, 23591959),
#  (3044, 23429478),
#  (315, 23376046),
#  (462, 22823784),
# ...

# %%
subset_selected = np.array(subset_selected)

# %% [markdown]
# This is the 30% list according to Li: the total duration of trips from station i through 06/2017 ~ 09/2017

# %%
subset_selected
# Out:
# array([ 281,  426,  514, 3068, 3042, 2006,  519,  387,  497, 3002, 3374,
#         459, 3255, 2008, 3256,  499,  151,  402, 3282,  490,  327,  217,
#         435,  523, 3137, 3165,  477, 3052, 3058,  359,  405,  457,  368,
#         358,  444, 3067, 3041,  304,  293,  285,  450, 3163, 3047,  279,
#        3435,  532, 3044,  315,  462, 3224,  530, 3423,  168,  505,  284,
#         128,  458,  479, 3427,  501,  379, 3168,  465, 3263, 3418,  492,
#         380,  127,  382,  347,  229, 3349, 3443,  432,  259, 3164,  323,
#        3160,  518, 3016,  437,  504, 3143,  336, 3064,  447, 3440,  173,
#         433,  363,  161,  251, 2021,  491,  461,  417,  445,  312, 3254,
#         442, 3141,  195,  265, 3383,  401,  527,  529,  525,  509,  478,
#         446,  508,   83,  236, 3180, 3166,   72,  212,  537,  412,  410,
#         377,  486, 3046, 3428,  237, 3167,  267,  545,  309,  496,  507,
#         427,  468,  494, 3074,  319,  498,  539, 3458,  531, 3260,  517,
# ...

# %%
import Sim_random_pick_CRN_751
from datetime import timedelta as td
from datetime import datetime as time

# %%
start_time = time(2017,7,1,hour= 6)
end_time=start_time+ td(weeks=35)

# %%
initial_stations=eval(open(("steady_states_751/steady_ebikes_initial_0.5.txt")).read())
for station in initial_stations.keys():
    if station in subset_selected:
        initial_stations[station]['edock'] = initial_stations[station]['ecap']
    else:
        initial_stations[station]['edock'] = 0

# %%
gc=Sim_random_pick_CRN_751.GlobalClock(start_time,end_time,initial_stations)
gc.clockAdvance() 
# out_of_battery
w_out_of_battery=list(gc.week_out_of_battery.values())[2:]
x=range(0,len(w_out_of_battery))    
with open('total_duration.csv','w') as f:
    f.write('week,out_of_battery_trips\n')
    for week in x:
        f.write(str(week+1)+','+str(w_out_of_battery[week])+'\n')
# Out:
# the total number of ebikes: 11051
# the total number of regular bikes: 0
# total_energy: 0
# 2017-07-01 06:00:01.005679 0
# total_energy: 2161748.7971022073
# 2017-07-08 06:00:00.957028 1
# total_energy: 4338929.263812799
# 2017-07-15 06:00:00.213000 2
# total_energy: 6506137.145637631
# 2017-07-22 06:00:02.992677 3
# total_energy: 8686451.851647612
# 2017-07-29 06:00:02.115819 4
# total_energy: 10866279.84994347
# 2017-08-05 06:00:01.232106 5
# total_energy: 13044465.888126368
# 2017-08-12 06:00:00.184050 6
# total_energy: 15224048.789472735
# 2017-08-19 06:00:03.721953 7
# total_energy: 17399135.95283593
# 2017-08-26 06:00:02.854444 8
# total_energy: 19582820.373891704
# 2017-09-02 06:00:00.491973 9
# total_energy: 21770441.57620772
# 2017-09-09 06:00:00.349803 10
# total_energy: 23949708.448831595
# 2017-09-16 06:00:00.933500 11
# total_energy: 26128255.65159013
# 2017-09-23 06:00:02.552255 12
# total_energy: 28318078.01336756
# 2017-09-30 06:00:01.348402 13
# ...

# %%
dropped_list = []
for k in station_duration.keys():
    if station_duration[k] == 0:
        dropped_list.append(k)

# %%
len(dropped_list)
# Out:
# 57

# %%
complete_list = [x for x in station_duration.keys() if x not in dropped_list]
complete_list
# Out:
# [72,
#  79,
#  82,
#  83,
#  116,
#  119,
#  120,
#  127,
#  128,
#  143,
#  144,
#  146,
#  150,
#  151,
#  152,
#  153,
#  157,
#  161,
#  164,
#  167,
#  168,
#  173,
#  174,
#  195,
#  212,
#  216,
#  217,
#  223,
#  224,
#  228,
#  229,
#  232,
#  236,
#  237,
#  238,
#  239,
#  241,
#  242,
#  243,
#  244,
#  245,
#  247,
#  248,
#  249,
#  251,
#  252,
#  253,
#  254,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  264,
#  265,
#  266,
#  267,
#  268,
#  270,
#  274,
#  275,
#  276,
#  278,
#  279,
#  280,
#  281,
#  282,
#  284,
#  285,
#  289,
#  291,
#  293,
#  295,
#  296,
#  297,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  330,
#  331,
#  332,
#  334,
#  335,
#  336,
#  337,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  353,
#  354,
# ...

# %%
len(complete_list)
# Out:
# 694

# %%
694+57
# Out:
# 751

# %%
complete_list = np.array(complete_list)

# %%
dropped_list
# Out:
# [533,
#  3183,
#  3184,
#  3185,
#  3186,
#  3187,
#  3188,
#  3192,
#  3193,
#  3194,
#  3197,
#  3199,
#  3201,
#  3202,
#  3203,
#  3205,
#  3211,
#  3213,
#  3214,
#  3240,
#  3247,
#  3253,
#  3267,
#  3273,
#  3275,
#  3276,
#  3299,
#  3471,
#  3480,
#  3481,
#  3527,
#  3555,
#  3557,
#  3597,
#  3611,
#  3615,
#  3623,
#  3625,
#  3629,
#  3636,
#  3641,
#  3646,
#  3647,
#  3648,
#  3649,
#  3656,
#  3659,
#  3666,
#  3669,
#  3671,
#  3674,
#  3676,
#  3677,
#  3679,
#  3684,
#  3686,
#  3689]

# %%
3201 in s
# Out:
# False

# %%
b = False
for l in dropped_list:
    b = b or l in s
b
# Out:
# True

# %%
s = [3254, 3267, 3199, 3202, 3276, 3192, 3186, 3183, 3213, 3072, 3178, 3290, 491, 3285, 3314, 411, 3165, 383, 527, 3357, 347, 474, 484, 504, 3244, 2021, 3282, 528, 529, 2008, 531, 518, 3383, 3427, 3443, 3137, 3139, 3156, 426, 3436, 3372, 3376, 3184, 363, 3134, 3163, 3283, 3286, 444, 472, 3293, 3295, 281, 514, 402, 3132, 285, 3164, 435, 423, 486, 3173, 3224, 537, 3056, 365, 252, 3146, 359, 387, 388, 405, 410, 3203, 3211, 152, 284, 434, 3129, 3151, 3323, 328, 490, 280, 540, 146, 3341, 3349, 3366, 3367, 3162, 3336, 3167, 503, 507, 315, 3150, 319, 229, 238, 442, 3226, 327, 446, 479, 499, 508, 513, 316, 335, 3145, 173, 3258, 127, 305, 309, 3214, 223, 356, 3320, 128, 296, 433, 3306, 3307, 3308, 3310, 2000, 3312, 3315, 3316, 2002, 3318, 2003, 3321, 3325, 3328, 3329, 3331, 2006, 432, 3297, 3298, 3343, 3346, 3303, 3351, 3355, 3356, 3304, 3358, 3359, 3360, 3361, 3362, 3370, 3311, 340, 421, 422, 427, 430, 336, 539, 545, 3319, 546, 428, 3284, 523, 251, 397, 3148, 3479, 3157, 3288, 3158, 419, 420, 3294, 332, 249, 396, 3141, 3142, 3292, 3263, 536, 248, 3289, 3259, 3260, 395, 3428, 3136, 3429, 3434, 3435, 3373, 3438, 3378, 3440, 3423, 3447, 3449, 3453, 3382, 3454, 3457, 3459, 3461, 3462, 3463, 3464, 3466, 519, 459, 497, 3002, 368, 358, 3256, 151, 293, 382]

# %%
coordinates = pd.read_csv("bike_coordinates.csv")

# %%
coordinates.head()
# Out:
#    stationid        lat        lon     gradient
# 0         72  40.767272 -73.993929  97027.97754
# 1         79  40.719116 -74.006667  62978.73222
# 2         82  40.711174 -74.000165  23706.99516
# 3         83  40.683826 -73.976323  30608.93818
# 4        116  40.741776 -74.001497  90845.87259

# %%
complete_list = [x for x in station_duration.keys() if x not in dropped_list]
complete_list

# %%
len(coordinates)
# Out:
# 751

# %%
b = True
for l in station_duration.keys():
    b = b and l in coordinates['stationid']
b
# Out:
# False

# %%
len(station_duration.keys())
# Out:
# 751

# %%
lat = []
lon = []
for k in station_duration.keys():
    df = coordinates[coordinates['stationid']==k]
    lat.append(df['lat'])
    lon.append(df['lon'])

# %%
sorted_list = sorted(station_duration.keys())
sorted_list
# Out:
# [72,
#  79,
#  82,
#  83,
#  116,
#  119,
#  120,
#  127,
#  128,
#  143,
#  144,
#  146,
#  150,
#  151,
#  152,
#  153,
#  157,
#  161,
#  164,
#  167,
#  168,
#  173,
#  174,
#  195,
#  212,
#  216,
#  217,
#  223,
#  224,
#  228,
#  229,
#  232,
#  236,
#  237,
#  238,
#  239,
#  241,
#  242,
#  243,
#  244,
#  245,
#  247,
#  248,
#  249,
#  251,
#  252,
#  253,
#  254,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  264,
#  265,
#  266,
#  267,
#  268,
#  270,
#  274,
#  275,
#  276,
#  278,
#  279,
#  280,
#  281,
#  282,
#  284,
#  285,
#  289,
#  291,
#  293,
#  295,
#  296,
#  297,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  330,
#  331,
#  332,
#  334,
#  335,
#  336,
#  337,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  353,
#  354,
# ...

# %%
df = pd.DataFrame(sorted_list)

# %%
df.to_csv("data.csv")

# %%
values = []
stations = []
for k in station_duration.keys():
    stations.append(k)
    values.append(station_duration[k])

# %%
df1 = pd.DataFrame({'stationid':stations,'duration':values})

# %%
df1.head()
# Out:
#    stationid  duration
# 0         72  17058703
# 1         79   8721961
# 2         82   6808909
# 3         83  17348578
# 4        116  12726742

# %%
df1.to_csv("Li.csv")

# %%
df2 = pd.read_csv("bike_coordinates copy 2.csv")
df2.head()
# Out:
#    stationid  Index  indicator        lat        lon  Index.1    duration  \
# 0       72.0    1.0        1.0  40.767272 -73.993929      1.0  17058703.0
# 1       79.0    2.0        1.0  40.719116 -74.006667      2.0   8721961.0
# 2       82.0    3.0        NaN  40.711174 -74.000165      3.0   6808909.0
# 3       83.0    4.0        NaN  40.683826 -73.976323      4.0  17348578.0
# 4      116.0    5.0        1.0  40.741776 -74.001497      5.0  12726742.0
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN        72.0
# 1         NaN        79.0
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN       116.0

# %%
df3 = df2[df2['indicator']!=1]
df3.head()
# Out:
#     stationid  Index  indicator        lat        lon  Index.1    duration  \
# 2        82.0    3.0        NaN  40.711174 -74.000165      3.0   6808909.0
# 3        83.0    4.0        NaN  40.683826 -73.976323      4.0  17348578.0
# 6       120.0    7.0        NaN  40.686768 -73.959282      7.0   3314874.0
# 9       143.0   10.0        NaN  40.692395 -73.993379     10.0   6971147.0
# 10      144.0   11.0        NaN  40.698399 -73.980689     11.0   6412858.0
#
#     Unnamed: 7  Unnamed: 8
# 2          NaN         NaN
# 3          NaN         NaN
# 6          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN

# %%
l7 = np.array(df3['stationid'])
l7
# Out:
# array([  82.,   83.,  120.,  143.,  144.,  150.,  151.,  153.,  157.,
#         161.,  164.,  167.,  173.,  174.,  216.,  217.,  228.,  229.,
#         232.,  236.,  237.,  239.,  241.,  243.,  245.,  251.,  252.,
#         257.,  258.,  261.,  265.,  266.,  268.,  274.,  275.,  278.,
#         279.,  280.,  281.,  282.,  285.,  289.,  291.,  293.,  295.,
#         296.,  297.,  301.,  302.,  303.,  305.,  307.,  308.,  310.,
#         311.,  312.,  314.,  317.,  321.,  322.,  323.,  324.,  325.,
#         326.,  331.,  332.,  335.,  336.,  339.,  340.,  341.,  342.,
#         348.,  349.,  350.,  353.,  355.,  356.,  357.,  359.,  361.,
#         362.,  365.,  382.,  384.,  385.,  386.,  387.,  389.,  390.,
#         391.,  392.,  393.,  394.,  395.,  397.,  398.,  399.,  400.,
#         401.,  403.,  406.,  407.,  408.,  410.,  411.,  412.,  414.,
#         416.,  418.,  420.,  428.,  430.,  432.,  433.,  438.,  439.,
# ...

# %%
len(l2)
# Out:
# 225

# %%
start_time = time(2017,7,1,hour= 6)
end_time=start_time+ td(weeks=35)
initial_stations=eval(open(("steady_states_751/steady_ebikes_initial_0.5.txt")).read())
for station in initial_stations.keys():
    if station in l2:
        initial_stations[station]['edock'] = initial_stations[station]['ecap']
    else:
        initial_stations[station]['edock'] = 0
gc=Sim_random_pick_CRN_751.GlobalClock(start_time,end_time,initial_stations)
gc.clockAdvance() 
# out_of_battery
w_out_of_battery=list(gc.week_out_of_battery.values())[2:]
x=range(0,len(w_out_of_battery))    
with open('nearest_assignment.csv','w') as f:
    f.write('week,out_of_battery_trips\n')
    for week in x:
        f.write(str(week+1)+','+str(w_out_of_battery[week])+'\n')
# Out:
# the total number of ebikes: 11051
# the total number of regular bikes: 0
# total_energy: 0
# 2017-07-01 06:00:01.005679 0
# total_energy: 2161919.1116744094
# 2017-07-08 06:00:00.057243 1
# total_energy: 4344213.038807949
# 2017-07-15 06:00:03.349367 2
# total_energy: 6504839.0876169065
# 2017-07-22 06:00:01.446495 3
# total_energy: 8680607.452290341
# 2017-07-29 06:00:01.244460 4
# total_energy: 10854380.4470657
# 2017-08-05 06:00:04.054423 5
# total_energy: 13029521.360993216
# 2017-08-12 06:00:00.719808 6
# total_energy: 15208128.30693714
# 2017-08-19 06:00:00.151583 7
# total_energy: 17377617.26219353
# 2017-08-26 06:00:00.677459 8
# total_energy: 19556319.419020094
# 2017-09-02 06:00:02.185154 9
# total_energy: 21737019.432013776
# 2017-09-09 06:00:00.211786 10
# total_energy: 23913029.535230245
# 2017-09-16 06:00:02.890512 11
# total_energy: 26085162.632908743
# 2017-09-23 06:00:00.568426 12
# total_energy: 28274209.821783982
# 2017-09-30 06:00:02.696921 13
# ...

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key='AIzaSyC2xPowUkGn2BChUBw4l9tuezByrIhxJHU')

# %%
station_coord = pd.read_csv("bike_coordinates.csv")
rows_to_delete = []
for i in range(len(station_coord)):
    if (station_coord.loc[i,'stationid'] not in l7):
        rows_to_delete.append(i)
df = station_coord.drop(rows_to_delete)

# %%
df = station_coord[['lat', 'lon']]

# %%
layer = gmaps.symbol_layer(df, fill_color='red', stroke_color='red', scale=1)
fig = gmaps.figure()
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
l3 = [ 281,  426,  514, 3068, 3042, 2006,  519,  387,  497, 3002, 3374,
        459, 3255, 2008, 3256,  499,  151,  402, 3282,  490,  327,  217,
        435,  523, 3137, 3165,  477, 3052, 3058,  359,  405,  457,  368,
        358,  444, 3067, 3041,  304,  293,  285,  450, 3163, 3047,  279,
       3435,  532, 3044,  315,  462, 3224,  530, 3423,  168,  505,  284,
        128,  458,  479, 3427,  501,  379, 3168,  465, 3263, 3418,  492,
        380,  127,  382,  347,  229, 3349, 3443,  432,  259, 3164,  323,
       3160,  518, 3016,  437,  504, 3143,  336, 3064,  447, 3440,  173,
        433,  363,  161,  251, 2021,  491,  461,  417,  445,  312, 3254,
        442, 3141,  195,  265, 3383,  401,  527,  529,  525,  509,  478,
        446,  508,   83,  236, 3180, 3166,   72,  212,  537,  412,  410,
        377,  486, 3046, 3428,  237, 3167,  267,  545,  309,  496,  507,
        427,  468,  494, 3074,  319,  498,  539, 3458,  531, 3260,  517,
       3158, 3173,  453,  361,  483,  297,  487,  448,  334,  460,  524,
       2000, 3175,  526,  472,  466, 3244,  434,  328,  383, 3295,  534,
        503,  167, 3236,  428, 3080, 3142,  482, 3258, 3182,  268, 3136,
       3429,  366,  439,  305,  301,  438, 3093,  495,  345, 3059,  348,
        520, 2010, 3159, 3233, 3472,  513,  474,  386, 3259,  484, 3323,
       3140, 2002,  257,  540,  515,  351,  355,  307,  476,  480,  303,
        384, 3129,  536,  430, 2003,  546,  116, 3223,  238,  326, 3249,
        392,  388, 3436, 3179,  325]

# %%
l4 = [3260,
3263,
3282,
3283,
3284,
3285,
3286,
3288,
3289,
3290,
3292,
3293,
3294,
3295,
3296,
3297,
3298,
3300,
3301,
3302,
3303,
3304,
3305,
3306,
3307,
3308,
3309,
3310,
3311,
3312,
3313,
3314,
3315,
3316,
3317,
3318,
3319,
3320,
3321,
3322,
3323,
3324,
3325,
3326,
3327,
3328,
3329,
3330]

# %%
l5 = [3367,
3368,
3369,
3370,
3371,
3372,
3373,
3374,
3375,
3376,
3377,
3378,
3379,
3381,
3382,
3383,
3384,
3386,
3387,
3388,
3389,
3390,
3391,
3392,
3393,
3394,
3395,
3396,
3397,
3398,
3399,
3400,
3401,
3402,
3403,
3404,
3405,
3407,
3408,
3409,
3410,
3411,
3412,
3413,
3414,
3415,
3416,
3417,
3418,
3419,
3420,
3421,
3422,
3423,
3424,
3425,
3427]

# %%
l6 = [3112,
3113,
3115,
3116,
3117,
3118,
3119,
3120,
3121,
3122,
3123,
3124,
3125,
3126,
3127,
3128,
3129,
3130,
3131,
3132,
3134,
3135,
3136,
3137,
3139,
3140,
3141,
3142,
3143,
3144,
3145,
3146,
3147,
3148,
3150,
3151,
3152,
3155,
3156,
3157,
3158,
3159,
3160,
3161,
3162,
3163,
3164,
3165]
