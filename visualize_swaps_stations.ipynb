# %% [markdown]
# Visualize the swap decisions for gradient method using gmaps

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key='AIzaSyC2xPowUkGn2BChUBw4l9tuezByrIhxJHU')
df = df[['lat', 'lon']]
layer = gmaps.symbol_layer(
    df, fill_color='green', stroke_color='green', scale=1
)
df3 = df3[['lat', 'lon']]
layer3 = gmaps.symbol_layer(
    df3, fill_color='green', stroke_color='blue', scale=2
)
fig = gmaps.figure()
fig.add_layer(layer)
fig.add_layer(layer3)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# 3481->519
# 2005->497
# 3338->459
# 3352->358
# 3345->3002
# 3441->368
# 3379->3256
# 3128->151
# 3479->293
# 3214->382
# 3211->168
# 3359->3255
# 3343->505
# 3157->477
# 3341->3374
# 2001->379
# 3355->457
# 3325->509

# %%
to_be_replaced = [3481,2005,3338,3352,3345,3441,3379,3128,3479,3214,3211,3359,3343,3157,3341,2001,3355,3325]

# %%
swap_six_pairs = [3254, 3267, 3199, 3202, 3276, 3192, 3186, 3183, 237, 3072, 3178, 3290, 491, 3285, 3314, 411, 3165, 3205, 383, 527, 3357, 347, 474, 484, 504, 3244, 2021, 3282, 528, 529, 2008, 531, 518, 3383, 3427, 3443, 3137, 3139, 3156, 426, 3436, 3372, 3376, 3184, 363, 3134, 3163, 3283, 3286, 444, 472, 3293, 3295, 281, 514, 402, 3132, 285, 3164, 435, 423, 486, 3173, 3224, 537, 3056, 365, 252, 3146, 359, 387, 388, 405, 410, 3203, 152, 284, 434, 3129, 3151, 3323, 328, 490, 280, 540, 146, 3349, 3366, 3367, 3162, 3336, 3167, 503, 507, 315, 3150, 319, 229, 238, 442, 3226, 327, 446, 479, 499, 508, 513, 316, 335, 3145, 173, 3258, 127, 305, 309, 223, 356, 3320, 128, 296, 433, 3306, 3307, 3308, 3310, 2000, 3312, 3315, 2002, 3318, 2003, 3321, 3328, 3329, 3331, 2006, 432, 3297, 3298, 3346, 3303, 3351, 324, 3304, 3358, 3360, 3361, 3362, 83, 3311, 340, 217, 422, 427, 430, 336, 539, 545, 3319, 546, 428, 523, 251, 397, 3148, 3288, 3158, 419, 3409, 3294, 332, 249, 396, 3141, 3142, 3292, 3263, 536, 3016, 3289, 3259, 3260, 395, 3428, 3136, 3429, 3434, 3435, 3373, 3438, 3378, 3440, 3423, 3447, 3449, 3453, 3382, 3454, 3457, 3459, 3461, 3462, 3463, 3464, 3466, 519, 497, 459, 358, 3002, 368, 3256, 151, 293, 382, 168, 3255, 505, 477, 3374, 379, 457, 509, 458, 462]

# %%
replaced_by = [519,497,459,358,3002,368,3256,151,293,382,168,3255,505,477,3374,379,457,509]

# %%
all_30percent = [3254, 3267, 3199, 3202, 3276, 3192, 3186, 3183, 3213, 3072, 3178, 3290, 
     491, 3285, 3314, 411, 3165, 3205, 383, 527, 3357, 347, 474, 484, 504, 3244, 
     2021, 3282, 528, 529, 2008, 531, 518, 3383, 3427, 3443, 3137, 3139, 3156, 426, 
     3436, 3372, 3376, 3184, 363, 3134, 3163, 3283, 3286, 444, 472, 3293, 3295, 281,
    514, 402, 3132, 285, 3164, 435, 423, 486, 3173, 3224, 537, 3056, 365, 252, 3146, 
    359, 387, 388, 405, 410, 3203, 3211, 152, 284, 434, 3129, 3151, 3323, 328, 490, 
    280, 540, 146, 3341, 3349, 3366, 3367, 3162, 3336, 3167, 503, 507, 315, 3150, 
    319, 229, 238, 442, 3226, 327, 446, 479, 499, 508, 513, 316, 335, 3145, 173, 
    3258, 127, 305, 309, 3214, 223, 356, 3320, 3481, 128, 296, 433, 3306, 3307, 
    3308, 3310, 2000, 3312, 2001, 3315, 3316, 2002, 3318, 2003, 3321, 3325, 3328, 
    3329, 3331, 3338, 2005, 2006, 432, 3297, 3298, 3343, 3345, 3346, 3303, 3351, 
    3352, 3355, 3356, 3304, 3358, 3359, 3360, 3361, 3362, 3370, 3311, 340, 421, 
    422, 427, 430, 336, 539, 545, 3319, 546, 428, 3284, 523, 251, 397, 3148, 3479,
    3157, 3288, 3158, 419, 420, 3294, 332, 249, 396, 3141, 3142, 3292, 3263, 536,
    248, 3289, 3259, 3260, 395, 3128, 3428, 3136, 3429, 3434, 3435, 3373, 3438, 
    3378, 3440, 3441, 3379, 3423, 3447, 3449, 3453, 3382, 3454, 3457, 3459, 3461, 
    3462, 3463, 3464, 3466]

# %%
import pandas as pd

# %%
station_coord = pd.read_csv("bike_coordinates.csv")
rows_to_delete = []
for i in range(len(station_coord)):
    if (station_coord.loc[i,'stationid'] not in substitute):
        rows_to_delete.append(i)
df3 = station_coord.drop(rows_to_delete)

# %%
df3.head()
# Out:
#      stationid        lat        lon  duration      gradient
# 3           83  40.683826 -73.976323  17348578   30608.93818
# 26         217  40.702772 -73.993836  29642255   65142.57785
# 33         237  40.730473 -73.986724  16498530  127543.40590
# 98         324  40.689888 -73.981013   7633119   23200.90069
# 287       3016  40.720368 -73.961651  19611981   46648.97714

# %%
gradient = df['gradient']
#scaling 
grad_range = max(gradient) - min(gradient)
m = min(gradient)
gradients = []
for i in gradient:
    gradients.append((i-m)/grad_range)

# %%
gradients
# Out:
# [0.5442418660249664,
#  0.5984586217862907,
#  0.278667322607294,
#  0.2593090805988777,
#  0.46243392345670065,
#  0.28157804060812225,
#  0.6078059111724797,
#  0.2952312224489975,
#  0.09200758704397072,
#  0.1970277116646716,
#  0.5344239876253346,
#  0.31336720262067824,
#  0.26672794186820936,
#  0.34763665994281406,
#  0.6477883917669061,
#  0.7415367448568071,
#  0.34761760896562616,
#  0.34204114054277324,
#  0.37756908739574646,
#  0.5391341193592443,
#  0.18786772965876009,
#  0.3850606978194661,
#  0.723810642754228,
#  0.338642935169056,
#  0.20924865948699575,
#  0.30029923243557577,
#  0.4157600501238039,
#  0.17538530229677263,
#  0.5241130166819541,
#  0.158164565280552,
#  0.450486117151251,
#  0.5004084035199453,
#  0.19636064390268423,
#  0.4220117751410883,
#  0.9186329284336193,
#  0.3403140082995209,
#  0.2178362180914836,
#  0.24134389404559603,
#  0.1187531019921176,
#  0.5870297322334127,
#  0.5729951026065215,
#  0.47499717412064263,
# ...

# %%
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(df[['lat', 'lon']], weights=gradient,
    max_intensity=100000, point_radius=3.5)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
layer = gmaps.symbol_layer(
    df[['lat', 'lon']], fill_color='rgba(200, 0, 0, 0.4)',
    stroke_color='rgba(200, 0, 0, 0.4)', scale=2
)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
station_coord = pd.read_csv("bike_coordinates.csv")
rows_to_delete = []
for i in range(len(station_coord)):
    if (station_coord.loc[i,'stationid'] not in to_be_replaced):
        rows_to_delete.append(i)
df = station_coord.drop(rows_to_delete)
import gmaps
import gmaps.datasets
gmaps.configure(api_key='AIzaSyDRAayFJjl7lsFcHLyWTlgnqToj6cXs6Ew')
df = df[['lat', 'lon']]
layer = gmaps.symbol_layer(
    df, fill_color='green', stroke_color='green', scale=2
)
fig = gmaps.figure()
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
original = [3254, 3267, 3199, 3202, 3276, 3192, 3186, 3183, 3213, 3072, 3178, 3290, 491, 3285, 3314, 411, 3165, 3205, 383, 527, 3357, 347, 474, 484, 504, 3244, 2021, 3282, 528, 529, 2008, 531, 518, 3383, 3427, 3443, 3137, 3139, 3156, 426, 3436, 3372, 3376, 3184, 363, 3134, 3163, 3283, 3286, 444, 472, 3293, 3295, 281, 514, 402, 3132, 285, 3164, 435, 423, 486, 3173, 3224, 537, 3056, 365, 252, 3146, 359, 387, 388, 405, 410, 3203, 152, 284, 434, 3129, 3151, 3323, 328, 490, 280, 540, 146, 3349, 3366, 3367, 3162, 3336, 3167, 503, 507, 315, 3150, 319, 229, 238, 442, 3226, 327, 446, 479, 499, 508, 513, 316, 335, 3145, 173, 3258, 127, 305, 309, 223, 356, 3320, 128, 296, 433, 3306, 3307, 3308, 3310, 2000, 3312, 3315, 2002, 3318, 2003, 3321, 3328, 3329, 3331, 2006, 432, 3297, 3298, 3346, 3303, 3351, 3356, 3304, 3358, 3360, 3361, 3362, 3370, 3311, 340, 421, 422, 427, 430, 336, 539, 545, 3319, 546, 428, 523, 251, 397, 3148, 3288, 3158, 419, 420, 3294, 332, 249, 396, 3141, 3142, 3292, 3263, 536, 248, 3289, 3259, 3260, 395, 3428, 3136, 3429, 3434, 3435, 3373, 3438, 3378, 3440, 3423, 3447, 3449, 3453, 3382, 3454, 3457, 3459, 3461, 3462, 3463, 3464, 3466, 519, 497, 459, 358, 3002, 368, 3256, 151, 293, 382, 168, 3255, 505, 477, 3374, 379, 457, 509, 458, 462]

# %%
replaced = [248,421,3356,3370,3213,420]

# %%
gmaps.configure(api_key='AIzaSyC2xPowUkGn2BChUBw4l9tuezByrIhxJHU')
df1 = df1[['lat', 'lon']]
layer1 = gmaps.symbol_layer(
    df1, fill_color='green', stroke_color='green', scale=1
)
df2 = df2[['lat', 'lon']]
layer2 = gmaps.symbol_layer(
    df2, fill_color='green', stroke_color='red', scale=2
)
fig = gmaps.figure()
fig.add_layer(layer1)
fig.add_layer(layer2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
substitute = [3016,217,324,83,237,3409]
